# %%
# !pip install bs4
# !pip install requests

# %%
#importing require libraries 

from bs4 import BeautifulSoup
import requests

# %%
page = requests.get("https://en.wikipedia.org/wiki/Main_Page")
page
# Out:
# <Response [200]>

# %%
page = requests.get("https://www.imdb.com/search/title/?groups=top_100&sort=user_rating,desc&count=100")
page
# Out:
# <Response [200]>

# %%
page = requests.get("https://www.icc-cricket.com/rankings/mens/team-rankings/odi")
page
# Out:
# <Response [200]>

# %%
page = requests.get("https://www.weather.gov/")
page
# Out:
# <Response [200]>

# %% [markdown]
# # WEB SCRAPING

# %%
import requests
import pandas as pd
import json
from bs4 import BeautifulSoup
import time
import datetime

# %%
HEADERS = ({
    'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
    'Accept-Language': 'en-US, en;q=0.5'
})

# %%
def get_body(url):
    page = requests.get(url,headers=HEADERS)
    return BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# # 1. Write a python program to display all the header tags from‘en.wikipedia.org/wiki/Main_Page’.

# %%
url = 'https://en.wikipedia.org/wiki/Main_Page'
body = get_body(url)

# %%
h_list = []
for i in range(1,7):
    h_list.append([one.text for one in body.findAll(f'h{i}') ])
all_headers = pd.DataFrame(h_list).T
all_headers.columns = [ f'h{i}' for i in range(1,7)]

# %%
all_headers
# Out:
#            h1                             h2                   h3    h4    h5  \
# 0   Main Page  From today's featured article     Personal tools\n  None  None
# 1        None               Did you know ...         Namespaces\n  None  None
# 2        None                    In the news           Variants\n  None  None
# 3        None                    On this day              Views\n  None  None
# 4        None       Today's featured picture               More\n  None  None
# 5        None       Other areas of Wikipedia           \nSearch\n  None  None
# 6        None    Wikipedia's sister projects         Navigation\n  None  None
# 7        None            Wikipedia languages         Contribute\n  None  None
# 8        None                Navigation menu              Tools\n  None  None
# 9        None                           None       Print/export\n  None  None
# 10       None                           None  In other projects\n  None  None
# ...

# %% [markdown]
# # 2. Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. Name, IMDB rating, Year of release).

# %%
url = 'https://www.imdb.com/chart/top?ref_=nv_mv_250'

# %%
all_divs = get_body(url).find_all('tr')

# %%
final_list = []
for i,one_div in enumerate(all_divs):
    if i == 0 :
        continue
    if i == 101:
        break
        
    title_column = one_div.find('td',{'class','titleColumn'})
    year = title_column.find('span').text.replace('(','').replace(')','')
    name = title_column.find('a').text
    rating = one_div.find('td',{'class','ratingColumn'}).find('strong').text
    final_list.append({'year':year,'name':name,'rating':rating})
    
final_df = pd.DataFrame(final_list)
final_df
# Out:
#     year                                   name rating
# 0   1994               The Shawshank Redemption    9.2
# 1   1972                          The Godfather    9.1
# 2   1974                 The Godfather: Part II    9.0
# 3   2008                        The Dark Knight    9.0
# 4   1957                           12 Angry Men    8.9
# ..   ...                                    ...    ...
# 95  2012                               The Hunt    8.3
# 96  2000                    Requiem for a Dream    8.3
# 97  1952                    Singin' in the Rain    8.3
# 98  1959                     North by Northwest    8.3
# 99  2004  Eternal Sunshine of the Spotless Mind    8.3
#
# [100 rows x 3 columns]

# %% [markdown]
# # 3. Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. Name, IMDB rating, Year of release)

# %%
url = 'https://www.imdb.com/india/top-rated-indian-movies/'

# %%
all_divs = get_body(url).find_all('tr')
final_list = []
for i,one_div in enumerate(all_divs):
    if i == 0 :
        continue
    if i == 101:
        break
        
    title_column = one_div.find('td',{'class','titleColumn'})
    year = title_column.find('span').text.replace('(','').replace(')','')
    name = title_column.find('a').text
    rating = one_div.find('td',{'class','ratingColumn'}).find('strong').text
    final_list.append({'year':year,'name':name,'rating':rating})
    
final_df = pd.DataFrame(final_list)
final_df
# Out:
#     year                               name rating
# 0   1987                            Nayakan    8.5
# 1   2003                         Anbe Sivam    8.5
# 2   2018                  Pariyerum Perumal    8.5
# 3   1979                        Hanky Panky    8.5
# 4   2018                  C/o Kancharapalem    8.5
# ..   ...                                ...    ...
# 95  1992                               Roja    8.1
# 96  2006                    Rang De Basanti    8.1
# 97  2001  Lagaan: Once Upon a Time in India    8.1
# 98  2019           Uri: The Surgical Strike    8.1
# 99  2012                            Kahaani    8.1
#
# [100 rows x 3 columns]

# %% [markdown]
# # 4. Write a python program to scrap book name, author name, genre and book review of any 5 books from ‘www.bookpage.com’

# %%
url = 'https://bookpage.com/reviews'

# %%
all_boxs = get_body(url).find_all('div',{'class','article-row'})

# %%
all_books = []
for i,one_box in enumerate(all_boxs):
    if i == 5:
        break
        
    book_name = one_box.find('h4').find('a').text
    author_name = one_box.find('p',{'class','sans'}).text
    genre = one_box.find('p',{'class','hidden-phone'}).text.replace('\n','')
    book_review = one_box.find('p',{'class','excerpt'}).text
    all_books.append({
        'book_name': book_name,'author_name': author_name,'genre': genre,'book_review': book_review
    })
    
book_df = pd.DataFrame(all_books)
book_df
# Out:
#                              book_name  \
# 0                        ★ The Maidens
# 1                            The Guide
# 2   ★ The Love Songs of W.E.B. Du Bois
# 3                           ★ Einstein
# 4            A Duke Worth Fighting For
#
#                                          author_name  \
# 0  \nAlex Michaelides, Louise Brealey, Kobna Hold...
# 1                                   \nPeter Heller\n
# 2                        \nHonorée Fanonne Jeffers\n
# 3                                \nTorben Kuhlmann\n
# 4                              \nChristina Britton\n
#
#                                       genre  \
# 0     Audio / Mystery & Suspense / Suspense
# 1  Fiction / Speculative Fiction / Thriller
# 2              Fiction / Historical Fiction
# 3      Children's / Children's Picture Book
# 4              Romance / Historical Romance
#
#                                          book_review
# 0  \nActors Louise Brealey and Kobna Holdbrook-Sm...
# ...

# %% [markdown]
# # 5. Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have to scrape:

# %% [markdown]
# i) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.

# %%
# Importing the important libraries.

from bs4 import BeautifulSoup
import requests
import re

# get the respone from the url in www.cricket.com
icc_url = 'https://www.icc-cricket.com/rankings/mens/team-rankings/odi'
resp = requests.get(icc_url)
resp
# Out:
# <Response [200]>

# %%
#Check the response
resp.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <meta name="twitter:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta property="og:type" content="website"/>\n<meta property="twitter:card" content="summary_large_image"/>\n<meta name="description" content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta property="twitter:site" content="@icc"/>\n<meta name="twitter:description" content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams."/>\n<meta name="twitter:image" content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg"/>\n<meta property="og:title" content="ICC Ranking for ODI teams International Cricket Council"/>\n<meta proper
# ...

# %%
# Using Soup
soup1 = BeautifulSoup(resp.content)
soup1
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Ranking for ODI teams International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Ranking for ODI teams International Cricket Council" property="og:title"/>
# ...

# %%
# Declaring the structured data in prettify()
print(soup1.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="ICC Ranking for ODI teams International Cricket Council" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# ...

# %%
# Extracting the team names from tags
teams = soup1.find_all('span', class_='u-hide-phablet')
teams[:10]
# Out:
# [<span class="u-hide-phablet">New Zealand</span>,
#  <span class="u-hide-phablet">England</span>,
#  <span class="u-hide-phablet">Australia</span>,
#  <span class="u-hide-phablet">India</span>,
#  <span class="u-hide-phablet">South Africa</span>,
#  <span class="u-hide-phablet">Pakistan</span>,
#  <span class="u-hide-phablet">Bangladesh</span>,
#  <span class="u-hide-phablet">West Indies</span>,
#  <span class="u-hide-phablet">Sri Lanka</span>,
#  <span class="u-hide-phablet">Afghanistan</span>]

# %%
len(teams)
# Out:
# 25

# %%
# Extracting top 20 the team names 
team_names = []
for i in teams:
    team_names.append(i.text)
team_names[1:11]
# Out:
# ['England',
#  'Australia',
#  'India',
#  'South Africa',
#  'Pakistan',
#  'Bangladesh',
#  'West Indies',
#  'Sri Lanka',
#  'Afghanistan',
#  'Netherlands']

# %%
matches1 = soup1.find_all('td', class_='rankings-block__banner--matches')
matches1
# Out:
# [<td class="rankings-block__banner--matches">17</td>]

# %%
matches2 = soup1.find_all('td', class_='table-body__cell u-center-text')
matches2
# Out:
# [<td class="table-body__cell u-center-text">32</td>,
#  <td class="table-body__cell u-center-text">3,793</td>,
#  <td class="table-body__cell u-center-text">28</td>,
#  <td class="table-body__cell u-center-text">3,244</td>,
#  <td class="table-body__cell u-center-text">32</td>,
#  <td class="table-body__cell u-center-text">3,624</td>,
#  <td class="table-body__cell u-center-text">22</td>,
#  <td class="table-body__cell u-center-text">2,267</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">2,524</td>,
#  <td class="table-body__cell u-center-text">29</td>,
#  <td class="table-body__cell u-center-text">2,639</td>,
#  <td class="table-body__cell u-center-text">30</td>,
#  <td class="table-body__cell u-center-text">2,523</td>,
#  <td class="table-body__cell u-center-text">29</td>,
#  <td class="table-body__cell u-center-text">2,303</td>,
#  <td class="table-body__cell u-center-text">17</td>,
# ...

# %%
matches_names = []
for i in matches2:
    matches_names.append(i.text)
matches_names[0:11:1]
# Out:
# ['32',
#  '3,793',
#  '28',
#  '3,244',
#  '32',
#  '3,624',
#  '22',
#  '2,267',
#  '27',
#  '2,524',
#  '29']

# %%
points = soup1.find_all('td', class_='table-body__cell u-center-text')
points[:20]
# Out:
# [<td class="table-body__cell u-center-text">32</td>,
#  <td class="table-body__cell u-center-text">3,793</td>,
#  <td class="table-body__cell u-center-text">28</td>,
#  <td class="table-body__cell u-center-text">3,244</td>,
#  <td class="table-body__cell u-center-text">32</td>,
#  <td class="table-body__cell u-center-text">3,624</td>,
#  <td class="table-body__cell u-center-text">22</td>,
#  <td class="table-body__cell u-center-text">2,267</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">2,524</td>,
#  <td class="table-body__cell u-center-text">29</td>,
#  <td class="table-body__cell u-center-text">2,639</td>,
#  <td class="table-body__cell u-center-text">30</td>,
#  <td class="table-body__cell u-center-text">2,523</td>,
#  <td class="table-body__cell u-center-text">29</td>,
#  <td class="table-body__cell u-center-text">2,303</td>,
#  <td class="table-body__cell u-center-text">17</td>,
# ...

# %%
points_names = []
for i in points:
    points_names.append(i.text)
points_names[1:20:2]
# Out:
# ['3,793',
#  '3,244',
#  '3,624',
#  '2,267',
#  '2,524',
#  '2,639',
#  '2,523',
#  '2,303',
#  '1,054',
#  '336']

# %%
rating = soup1.find_all('td', class_='table-body__cell u-text-right rating')
rating[:10]
# Out:
# [<td class="table-body__cell u-text-right rating">119</td>,
#  <td class="table-body__cell u-text-right rating">116</td>,
#  <td class="table-body__cell u-text-right rating">113</td>,
#  <td class="table-body__cell u-text-right rating">103</td>,
#  <td class="table-body__cell u-text-right rating">93</td>,
#  <td class="table-body__cell u-text-right rating">91</td>,
#  <td class="table-body__cell u-text-right rating">84</td>,
#  <td class="table-body__cell u-text-right rating">79</td>,
#  <td class="table-body__cell u-text-right rating">62</td>,
#  <td class="table-body__cell u-text-right rating">48</td>]

# %%
rating_names = []
for i in rating:
    rating_names.append(i.text)
rating_names[:10]
# Out:
# ['119', '116', '113', '103', '93', '91', '84', '79', '62', '48']

# %%
# Creating the DataFrame in python using the pandas 

import pandas as pd 
cricket_df = pd.DataFrame({})
cricket_df['Team Names'] = team_names[1:11]
cricket_df['Matches'] = matches_names[:20:2]
cricket_df['Points'] = points_names[1:20:2]
cricket_df['Ratings'] = rating_names[:10]

cricket_df
# Out:
#      Team Names Matches Points Ratings
# 0       England      32  3,793     119
# 1     Australia      28  3,244     116
# 2         India      32  3,624     113
# 3  South Africa      22  2,267     103
# 4      Pakistan      27  2,524      93
# 5    Bangladesh      29  2,639      91
# 6   West Indies      30  2,523      84
# 7     Sri Lanka      29  2,303      79
# 8   Afghanistan      17  1,054      62
# 9   Netherlands       7    336      48

# %%
#  Final Top 10 list of Cricket according to their rankings 


top_row = pd.DataFrame({'Team Names':['New Zealand'],'Matches':[117],'Points':[2054], 'Ratings':[121]})
# Concat with old DataFrame and reset the Index.
cricket_df = pd.concat([top_row, cricket_df]).reset_index(drop = True)
cricket_df
# Out:
#       Team Names Matches Points Ratings
# 0    New Zealand     117   2054     121
# 1        England      32  3,793     119
# 2      Australia      28  3,244     116
# 3          India      32  3,624     113
# 4   South Africa      22  2,267     103
# 5       Pakistan      27  2,524      93
# 6     Bangladesh      29  2,639      91
# 7    West Indies      30  2,523      84
# 8      Sri Lanka      29  2,303      79
# 9    Afghanistan      17  1,054      62
# 10   Netherlands       7    336      48

# %% [markdown]
# ii) Top 10 ODI Batsmen in men along with the records of their team and rating.

# %%
icc_mens_url = 'https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting'
response = requests.get(icc_mens_url)
response
# Out:
# <Response [200]>

# %%
# Using Soup
soup2 = BeautifulSoup(response.content)
soup2
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="Live Cricket Scores &amp; News International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="Live Cricket Scores &amp; News International Cricket Council" property="og:title"/>
# ...

# %%
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="Live Cricket Scores &amp; News International Cricket Council" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
#   <meta content="Live Cricket Scores &amp; News International Cricket Council" property="og:title"/>
# ...

# %%
# Extracting the team names from tags
player= soup2.find_all('td', class_='table-body__cell rankings-table__name name')
player[:10]
# Out:
# [<td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/164">Virat Kohli</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/107">Rohit Sharma</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/226">Ross Taylor</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/167">Aaron Finch</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/506">Jonny Bairstow</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/170">David Warner</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/834">Quinton de Kock</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
# ...

# %%
player_name = []
for i in player:
    player_name.append(i.text)
player_name[:9]
# Out:
# ['\nVirat Kohli\n',
#  '\nRohit Sharma\n',
#  '\nRoss Taylor\n',
#  '\nAaron Finch\n',
#  '\nJonny Bairstow\n',
#  '\nDavid Warner\n',
#  '\nQuinton de Kock\n',
#  '\nShai Hope\n',
#  '\nKane Williamson\n']

# %%
player_name = []
for i in player:
    player_name.append(i.text.replace('\n',''))
player_name[:9]
# Out:
# ['Virat Kohli',
#  'Rohit Sharma',
#  'Ross Taylor',
#  'Aaron Finch',
#  'Jonny Bairstow',
#  'David Warner',
#  'Quinton de Kock',
#  'Shai Hope',
#  'Kane Williamson']

# %%
pos= soup2.find_all('td', class_='table-body__cell table-body__cell--position u-text-right')
pos[:9]
# Out:
# [<td class="table-body__cell table-body__cell--position u-text-right">
#                              2
#          <span class="ranking-pos no-change"></span>
#  </td>, <td class="table-body__cell table-body__cell--position u-text-right">
#                              3
#          <span class="ranking-pos no-change"></span>
#  </td>, <td class="table-body__cell table-body__cell--position u-text-right">
#                              4
#          <span class="ranking-pos no-change"></span>
#  </td>, <td class="table-body__cell table-body__cell--position u-text-right">
#                              5
#          <span class="ranking-pos no-change"></span>
#  </td>, <td class="table-body__cell table-body__cell--position u-text-right">
#                              6
#          <span class="ranking-pos no-change"></span>
#  </td>, <td class="table-body__cell table-body__cell--position u-text-right">
#                              7
#          <span class="ranking-pos up">
# ...

# %%
position = []
for i in pos:
    position.append(i.text)
position[:9]
# Out:
# ['\n                            2\n        \n',
#  '\n                            3\n        \n',
#  '\n                            4\n        \n',
#  '\n                            5\n        \n',
#  '\n                            6\n        \n',
#  '\n                            7\n        \n\n\n\nThis player has moved up in the rankings since the previous rankings update\n\n',
#  '\n                            8\n        \n\n\n\nThis player has moved up in the rankings since the previous rankings update\n\n',
#  '\n\n\n\n\nThis player has moved down in the rankings since the previous rankings update\n\n',
#  '\n                            10\n        \n']

# %%
position = []
for i in pos:
    position.append(i.text.replace('\n',''))

position.insert(0,2)
position.insert(1,3)
position.insert(2,4)
position.insert(3,5)
position.insert(4,6)
position.insert(5,7)
position.insert(6,8)
position.insert(7,9)
position.insert(8,10)
position.insert(9,11)

position[:9]
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9, 10]

# %%
country = soup2.find_all('span', class_ = 'table-body__logo-text')
country[:9]
# Out:
# [<span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">NZ</span>]

# %%
country_name = []
for i in country:
    country_name.append(i.text)
country_name[:9]
# Out:
# ['IND', 'IND', 'NZ', 'AUS', 'ENG', 'AUS', 'SA', 'WI', 'NZ']

# %%
rating = soup2.find_all('td', class_ = 'table-body__cell rating')
rating[:9]
# Out:
# [<td class="table-body__cell rating">844</td>,
#  <td class="table-body__cell rating">813</td>,
#  <td class="table-body__cell rating">801</td>,
#  <td class="table-body__cell rating">779</td>,
#  <td class="table-body__cell rating">775</td>,
#  <td class="table-body__cell rating">762</td>,
#  <td class="table-body__cell rating">758</td>,
#  <td class="table-body__cell rating">758</td>,
#  <td class="table-body__cell rating">754</td>]

# %%
rating_men = []
for i in rating:
    rating_men.append(i.text)
rating_men[:9]
# Out:
# ['844', '813', '801', '779', '775', '762', '758', '758', '754']

# %%
import pandas as pd 
men_rank = pd.DataFrame({})
men_rank['Positions'] = position[:9]
men_rank['Player Name'] = player_name[:9]
men_rank['Team'] = country_name[:9]
men_rank['Ratings'] = rating_men[:9]

men_rank
# Out:
#    Positions      Player Name Team Ratings
# 0          2      Virat Kohli  IND     844
# 1          3     Rohit Sharma  IND     813
# 2          4      Ross Taylor   NZ     801
# 3          5      Aaron Finch  AUS     779
# 4          6   Jonny Bairstow  ENG     775
# 5          7     David Warner  AUS     762
# 6          8  Quinton de Kock   SA     758
# 7          9        Shai Hope   WI     758
# 8         10  Kane Williamson   NZ     754

# %%
top_row1 = pd.DataFrame({'Positions':[1],'Player Name':['Babar Azam'],'Team':['Pak'], 'Ratings':[873]})
# Concat with old DataFrame and reset the Index.
men_rank = pd.concat([top_row1, men_rank]).reset_index(drop = True)
men_rank
# Out:
#    Positions      Player Name Team Ratings
# 0          1       Babar Azam  Pak     873
# 1          2      Virat Kohli  IND     844
# 2          3     Rohit Sharma  IND     813
# 3          4      Ross Taylor   NZ     801
# 4          5      Aaron Finch  AUS     779
# 5          6   Jonny Bairstow  ENG     775
# 6          7     David Warner  AUS     762
# 7          8  Quinton de Kock   SA     758
# 8          9        Shai Hope   WI     758
# 9         10  Kane Williamson   NZ     754

# %% [markdown]
# iii) Top 10 ODI bowlers along with the records of their team andrating.

# %%
icc_bowler_url = 'https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling'
response_bow = requests.get(icc_bowler_url)
response_bow
# Out:
# <Response [200]>

# %%
# Using Soup
soup3 = BeautifulSoup(response_bow.content)
soup3
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="Live Cricket Scores &amp; News International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="Live Cricket Scores &amp; News International Cricket Council" property="og:title"/>
# ...

# %%
print(soup3.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="Live Cricket Scores &amp; News International Cricket Council" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
#   <meta content="Live Cricket Scores &amp; News International Cricket Council" property="og:title"/>
# ...

# %%
position_bow = soup3.find_all('td', class_ = 'table-body__cell table-body__cell--position u-text-right')
position_bow[:9]
# Out:
# [<td class="table-body__cell table-body__cell--position u-text-right">
#                              2
#          <span class="ranking-pos up">
#  <svg class="icon">
#  <use xlink:href="/resources/prod/v8.19.9/i/svg-output/icons.svg#icn-chevron-up" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  <span class="ranking-pos__tooltip">This player has moved up in the rankings since the previous rankings update</span>
#  </span>
#  </td>, <td class="table-body__cell table-body__cell--position u-text-right">
#                              3
#          <span class="ranking-pos down">
#  <svg class="icon">
#  <use xlink:href="/resources/prod/v8.19.9/i/svg-output/icons.svg#icn-chevron-down" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
#  </svg>
#  <span class="ranking-pos__tooltip">This player has moved down in the rankings since the previous rankings update</span>
#  </span>
#  </td>, <td class="table-body__cell table-body__cell--position u-text-right">
# ...

# %%
pos_bow = []
for i in position_bow:
    pos_bow.append(i.text)
pos_bow[:9]
# Out:
# ['\n                            2\n        \n\n\n\nThis player has moved up in the rankings since the previous rankings update\n\n',
#  '\n                            3\n        \n\n\n\nThis player has moved down in the rankings since the previous rankings update\n\n',
#  '\n                            4\n        \n\n\n\nThis player has moved down in the rankings since the previous rankings update\n\n',
#  '\n                            5\n        \n\n\n\nThis player has moved down in the rankings since the previous rankings update\n\n',
#  '\n                            6\n        \n\n\n\nThis player has moved down in the rankings since the previous rankings update\n\n',
#  '\n                            7\n        \n',
#  '\n                            8\n        \n',
#  '\n                            9\n        \n',
#  '\n                            10\n        \n']

# %%
pos_bow = []
for i in position_bow:
    pos_bow.append(i.text.replace('\n',''))

pos_bow.insert(5,7)
pos_bow.insert(6,8)
pos_bow.insert(7,9)
pos_bow.insert(8,10)
pos_bow[:9]
# Out:
# ['                            2        This player has moved up in the rankings since the previous rankings update',
#  '                            3        This player has moved down in the rankings since the previous rankings update',
#  '                            4        This player has moved down in the rankings since the previous rankings update',
#  '                            5        This player has moved down in the rankings since the previous rankings update',
#  '                            6        This player has moved down in the rankings since the previous rankings update',
#  7,
#  8,
#  9,
#  10]

# %%
bowler = soup3.find_all('td', class_="table-body__cell rankings-table__name name")
bowler[:9]
# Out:
# [<td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/857">Josh Hazlewood</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/4572">Mujeeb Ur Rahman</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/967">Chris Woakes</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/1597">Mehedi Hasan</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/1505">Matt Henry</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/1124">Jasprit Bumrah</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/mens/player-rankings/490">Mitchell Starc</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
# ...

# %%
bowler_name = []
for i in bowler:
    bowler_name.append(i.text)
bowler_name[:9]
# Out:
# ['\nJosh Hazlewood\n',
#  '\nMujeeb Ur Rahman\n',
#  '\nChris Woakes\n',
#  '\nMehedi Hasan\n',
#  '\nMatt Henry\n',
#  '\nJasprit Bumrah\n',
#  '\nMitchell Starc\n',
#  '\nShakib Al Hasan\n',
#  '\nKagiso Rabada\n']

# %%
bowler_name = []
for i in bowler:
    bowler_name.append(i.text.replace('\n',''))
bowler_name[:9]
# Out:
# ['Josh Hazlewood',
#  'Mujeeb Ur Rahman',
#  'Chris Woakes',
#  'Mehedi Hasan',
#  'Matt Henry',
#  'Jasprit Bumrah',
#  'Mitchell Starc',
#  'Shakib Al Hasan',
#  'Kagiso Rabada']

# %%
rating3 = soup3.find_all('td', class_= 'table-body__cell rating')
rating3[:9]
# Out:
# [<td class="table-body__cell rating">709</td>,
#  <td class="table-body__cell rating">708</td>,
#  <td class="table-body__cell rating">700</td>,
#  <td class="table-body__cell rating">692</td>,
#  <td class="table-body__cell rating">691</td>,
#  <td class="table-body__cell rating">679</td>,
#  <td class="table-body__cell rating">652</td>,
#  <td class="table-body__cell rating">650</td>,
#  <td class="table-body__cell rating">648</td>]

# %%
bowler_rating = []
for i in rating3:
    bowler_rating.append(i.text)
bowler_rating[:9]
# Out:
# ['709', '708', '700', '692', '691', '679', '652', '650', '648']

# %%
team3 = soup3.find_all('span',class_ = 'table-body__logo-text')
team3[:9]
# Out:
# [<span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">AFG</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">BAN</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">BAN</span>,
#  <span class="table-body__logo-text">SA</span>]

# %%
bowlers_team = []
for i in team3:
    bowlers_team.append(i.text)
bowlers_team[:9]
# Out:
# ['AUS', 'AFG', 'ENG', 'BAN', 'NZ', 'IND', 'AUS', 'BAN', 'SA']

# %%
import pandas as pd 
bolwer_rank = pd.DataFrame({})
bolwer_rank['Positions'] = pos_bow[:9]
bolwer_rank['Bowler Name'] = bowler_name[:9]
bolwer_rank['Team'] = bowlers_team[:9]
bolwer_rank['Ratings'] = bowler_rating[:9]

bolwer_rank
# Out:
#                                            Positions       Bowler Name Team  \
# 0                              2        This play...    Josh Hazlewood  AUS
# 1                              3        This play...  Mujeeb Ur Rahman  AFG
# 2                              4        This play...      Chris Woakes  ENG
# 3                              5        This play...      Mehedi Hasan  BAN
# 4                              6        This play...        Matt Henry   NZ
# 5                                                  7    Jasprit Bumrah  IND
# 6                                                  8    Mitchell Starc  AUS
# 7                                                  9   Shakib Al Hasan  BAN
# 8                                                 10     Kagiso Rabada   SA
#
#   Ratings
# 0     709
# 1     708
# 2     700
# 3     692
# 4     691
# 5     679
# 6     652
# 7     650
# 8     648

# %%
top_row2 = pd.DataFrame({'Positions':[1],'Bowler Name':['Trent Boult'],'Team':['NZ'], 'Ratings':[737]})
# Concat with old DataFrame and reset the Index.
bolwer_rank = pd.concat([top_row2, bolwer_rank]).reset_index(drop = True)
bolwer_rank
# Out:
#                                            Positions       Bowler Name Team  \
# 0                                                  1       Trent Boult   NZ
# 1                              2        This play...    Josh Hazlewood  AUS
# 2                              3        This play...  Mujeeb Ur Rahman  AFG
# 3                              4        This play...      Chris Woakes  ENG
# 4                              5        This play...      Mehedi Hasan  BAN
# 5                              6        This play...        Matt Henry   NZ
# 6                                                  7    Jasprit Bumrah  IND
# 7                                                  8    Mitchell Starc  AUS
# 8                                                  9   Shakib Al Hasan  BAN
# 9                                                 10     Kagiso Rabada   SA
#
#   Ratings
# 0     737
# 1     709
# 2     708
# 3     700
# 4     692
# 5     691
# 6     679
# 7     652
# 8     650
# 9     648

# %% [markdown]
# # 6. Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have toscrape:

# %% [markdown]
# i) Top 10 ODI teams in women’s cricket along with the records for matches, points andrating.

# %%
# Importing the important libraries.

from bs4 import BeautifulSoup
import requests
import re

# Download IMDB's Top 100 data
icc_url = 'https://www.icc-cricket.com/rankings/womens/team-rankings/odi'
resp = requests.get(icc_url)
resp
# Out:
# <Response [200]>

# %%
# Using Soup
soup1 = BeautifulSoup(resp.content)
soup1
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Ranking for ODI teams International Cricket Council" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Ranking for ODI teams International Cricket Council" property="og:title"/>
# ...

# %%
# Declaring the structured data in prettify()
print(soup1.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="ICC Ranking for ODI teams International Cricket Council" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
#   <meta content="ICC Ranking for ODI teams International Cricket Council" property="og:title"/>
# ...

# %%
# Extracting the team names from tags
teams = soup1.find_all('span', class_='u-hide-phablet')
teams[:10]
# Out:
# [<span class="u-hide-phablet">Australia</span>,
#  <span class="u-hide-phablet">England</span>,
#  <span class="u-hide-phablet">South Africa</span>,
#  <span class="u-hide-phablet">India</span>,
#  <span class="u-hide-phablet">New Zealand</span>,
#  <span class="u-hide-phablet">West Indies</span>,
#  <span class="u-hide-phablet">Pakistan</span>,
#  <span class="u-hide-phablet">Bangladesh</span>,
#  <span class="u-hide-phablet">Sri Lanka</span>,
#  <span class="u-hide-phablet">Ireland</span>]

# %%
len(teams)
# Out:
# 15

# %%
# Extracting top 20 the team names 
team_names = []
for i in teams:
    team_names.append(i.text)
team_names[1:10]
# Out:
# ['England',
#  'South Africa',
#  'India',
#  'New Zealand',
#  'West Indies',
#  'Pakistan',
#  'Bangladesh',
#  'Sri Lanka',
#  'Ireland']

# %%
matches2 = soup1.find_all('td', class_='table-body__cell u-center-text')
matches2
# Out:
# [<td class="table-body__cell u-center-text">20</td>,
#  <td class="table-body__cell u-center-text">2,370</td>,
#  <td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">2,828</td>,
#  <td class="table-body__cell u-center-text">23</td>,
#  <td class="table-body__cell u-center-text">2,535</td>,
#  <td class="table-body__cell u-center-text">21</td>,
#  <td class="table-body__cell u-center-text">1,947</td>,
#  <td class="table-body__cell u-center-text">17</td>,
#  <td class="table-body__cell u-center-text">1,427</td>,
#  <td class="table-body__cell u-center-text">20</td>,
#  <td class="table-body__cell u-center-text">1,496</td>,
#  <td class="table-body__cell u-center-text">5</td>,
#  <td class="table-body__cell u-center-text">306</td>,
#  <td class="table-body__cell u-center-text">11</td>,
#  <td class="table-body__cell u-center-text">519</td>,
#  <td class="table-body__cell u-center-text">2</td>,
# ...

# %%
matches_names = []
for i in matches2:
    matches_names.append(i.text)
matches_names[0:18:2]
# Out:
# ['20', '24', '23', '21', '17', '20', '5', '11', '2']

# %%
points = soup1.find_all('td', class_='table-body__cell u-center-text')
points[:20]
# Out:
# [<td class="table-body__cell u-center-text">20</td>,
#  <td class="table-body__cell u-center-text">2,370</td>,
#  <td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">2,828</td>,
#  <td class="table-body__cell u-center-text">23</td>,
#  <td class="table-body__cell u-center-text">2,535</td>,
#  <td class="table-body__cell u-center-text">21</td>,
#  <td class="table-body__cell u-center-text">1,947</td>,
#  <td class="table-body__cell u-center-text">17</td>,
#  <td class="table-body__cell u-center-text">1,427</td>,
#  <td class="table-body__cell u-center-text">20</td>,
#  <td class="table-body__cell u-center-text">1,496</td>,
#  <td class="table-body__cell u-center-text">5</td>,
#  <td class="table-body__cell u-center-text">306</td>,
#  <td class="table-body__cell u-center-text">11</td>,
#  <td class="table-body__cell u-center-text">519</td>,
#  <td class="table-body__cell u-center-text">2</td>,
# ...

# %%
points_names = []
for i in points:
    points_names.append(i.text)
points_names[1:20:2]
# Out:
# ['2,370', '2,828', '2,535', '1,947', '1,427', '1,496', '306', '519', '25']

# %%
rating = soup1.find_all('td', class_='table-body__cell u-text-right rating')
rating[:9]
# Out:
# [<td class="table-body__cell u-text-right rating">119</td>,
#  <td class="table-body__cell u-text-right rating">118</td>,
#  <td class="table-body__cell u-text-right rating">110</td>,
#  <td class="table-body__cell u-text-right rating">93</td>,
#  <td class="table-body__cell u-text-right rating">84</td>,
#  <td class="table-body__cell u-text-right rating">75</td>,
#  <td class="table-body__cell u-text-right rating">61</td>,
#  <td class="table-body__cell u-text-right rating">47</td>,
#  <td class="table-body__cell u-text-right rating">13</td>]

# %%
 rating_names = []
for i in rating:
    rating_names.append(i.text)
rating_names[:10]
# Out:
# ['119', '118', '110', '93', '84', '75', '61', '47', '13']

# %%
# Creating the DataFrame in python using the pandas 

import pandas as pd 
women_cricket_df = pd.DataFrame({})
women_cricket_df['Team Names'] = team_names[1:10]
women_cricket_df['Matches'] = matches_names[0:18:2]
women_cricket_df['Points'] = points_names[1:20:2]
women_cricket_df['Ratings'] = rating_names[:10]

women_cricket_df
# Out:
#      Team Names Matches Points Ratings
# 0       England      20  2,370     119
# 1  South Africa      24  2,828     118
# 2         India      23  2,535     110
# 3   New Zealand      21  1,947      93
# 4   West Indies      17  1,427      84
# 5      Pakistan      20  1,496      75
# 6    Bangladesh       5    306      61
# 7     Sri Lanka      11    519      47
# 8       Ireland       2     25      13

# %%
#  Final Top 10 list of Cricket according to their rankings 


top_row = pd.DataFrame({'Team Names':['Australia'],'Matches':[18],'Points':[2955], 'Ratings':[164]})
# Concat with old DataFrame and reset the Index.
women_cricket_df = pd.concat([top_row, women_cricket_df]).reset_index(drop = True)
women_cricket_df
# Out:
#      Team Names Matches Points Ratings
# 0     Australia      18   2955     164
# 1       England      20  2,370     119
# 2  South Africa      24  2,828     118
# 3         India      23  2,535     110
# 4   New Zealand      21  1,947      93
# 5   West Indies      17  1,427      84
# 6      Pakistan      20  1,496      75
# 7    Bangladesh       5    306      61
# 8     Sri Lanka      11    519      47
# 9       Ireland       2     25      13

# %% [markdown]
# ii) Top 10 women’s ODI players along with the records of their team and rating.

# %%
icc_womens_url = 'https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting'
response = requests.get(icc_womens_url)
response
# Out:
# <Response [200]>

# %%
soup2 = BeautifulSoup(response.content)
soup2
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="Live Cricket Scores &amp; News International Cricket Council" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
#   <meta content="Live Cricket Scores &amp; News International Cricket Council" property="og:title"/>
# ...

# %%
# Extracting the team names from tags
player= soup2.find_all('td', class_='table-body__cell rankings-table__name name')
player[:10]
# Out:
# [<td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/1785">Lizelle Lee</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/466">Alyssa Healy</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/545">Tammy Beaumont</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/469">Meg Lanning</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/487">Amy Satterthwaite</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/1800">Natalie Sciver</a>
# ...

# %%
player_name = []
for i in player:
    player_name.append(i.text)
player_name[:9]
# Out:
# ['\nLizelle Lee\n',
#  '\nAlyssa Healy\n',
#  '\nTammy Beaumont\n',
#  '\nStafanie Taylor\n',
#  '\nMeg Lanning\n',
#  '\nAmy Satterthwaite\n',
#  '\nNatalie Sciver\n',
#  '\nSmriti Mandhana\n',
#  '\nLaura Wolvaardt\n']

# %%
player_name = []
for i in player:
    player_name.append(i.text.replace('\n',''))
player_name[:9]
# Out:
# ['Lizelle Lee',
#  'Alyssa Healy',
#  'Tammy Beaumont',
#  'Stafanie Taylor',
#  'Meg Lanning',
#  'Amy Satterthwaite',
#  'Natalie Sciver',
#  'Smriti Mandhana',
#  'Laura Wolvaardt']

# %%
country = soup2.find_all('span', class_ = 'table-body__logo-text')
country[:9]
# Out:
# [<span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">SA</span>]

# %%
country_name = []
for i in country:
    country_name.append(i.text)
country_name[:9]
# Out:
# ['SA', 'AUS', 'ENG', 'WI', 'AUS', 'NZ', 'ENG', 'IND', 'SA']

# %%
rating = soup2.find_all('td', class_ = 'table-body__cell rating')
rating[:9]
# Out:
# [<td class="table-body__cell rating">758</td>,
#  <td class="table-body__cell rating">756</td>,
#  <td class="table-body__cell rating">754</td>,
#  <td class="table-body__cell rating">736</td>,
#  <td class="table-body__cell rating">723</td>,
#  <td class="table-body__cell rating">715</td>,
#  <td class="table-body__cell rating">706</td>,
#  <td class="table-body__cell rating">701</td>,
#  <td class="table-body__cell rating">683</td>]

# %%
rating_women = []
for i in rating:
    rating_women.append(i.text)
rating_women[:9]
# Out:
# ['758', '756', '754', '736', '723', '715', '706', '701', '683']

# %%
import pandas as pd 
women_rank = pd.DataFrame({})
#women_rank['Positions'] = position[:9]
women_rank['Player Name'] = player_name[:9]
women_rank['Team'] = country_name[:9]
women_rank['Ratings'] = rating_women[:9]

women_rank
# Out:
#          Player Name Team Ratings
# 0        Lizelle Lee   SA     758
# 1       Alyssa Healy  AUS     756
# 2     Tammy Beaumont  ENG     754
# 3    Stafanie Taylor   WI     736
# 4        Meg Lanning  AUS     723
# 5  Amy Satterthwaite   NZ     715
# 6     Natalie Sciver  ENG     706
# 7    Smriti Mandhana  IND     701
# 8    Laura Wolvaardt   SA     683

# %%
top_row1 = pd.DataFrame({'Player Name':['Mithali Raj'],'Team':['IND'], 'Ratings':[762]})
# Concat with old DataFrame and reset the Index.
women_rank = pd.concat([top_row1, women_rank]).reset_index(drop = True)
women_rank
# Out:
#          Player Name Team Ratings
# 0        Mithali Raj  IND     762
# 1        Lizelle Lee   SA     758
# 2       Alyssa Healy  AUS     756
# 3     Tammy Beaumont  ENG     754
# 4    Stafanie Taylor   WI     736
# 5        Meg Lanning  AUS     723
# 6  Amy Satterthwaite   NZ     715
# 7     Natalie Sciver  ENG     706
# 8    Smriti Mandhana  IND     701
# 9    Laura Wolvaardt   SA     683

# %% [markdown]
# iii) Top 10 women’s ODI all-rounder along with the records of their team andrating.

# %%
icc_allround_url = 'https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder'
response_all = requests.get(icc_allround_url)
response_all
# Out:
# <Response [200]>

# %%
# Using Soup
soup3 = BeautifulSoup(response_all.content)
soup3
print(soup3.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="Live Cricket Scores &amp; News International Cricket Council" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
#   <meta content="Live Cricket Scores &amp; News International Cricket Council" property="og:title"/>
# ...

# %%
all_rounder = soup3.find_all('td', class_="table-body__cell rankings-table__name name")
all_rounder[:9]
# Out:
# [<td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/471">Ellyse Perry</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/1800">Natalie Sciver</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/3192">Deepti Sharma</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/468">Jess Jonassen</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/4128">Ashleigh Gardner</a>
#  </td>, <td class="table-body__cell rankings-table__name name">
#  <a href="/rankings/womens/player-rankings/430">Dane van Niekerk</a>
# ...

# %%
allrounder_name = []
for i in all_rounder:
    allrounder_name.append(i.text)
allrounder_name[:9]
# Out:
# ['\nEllyse Perry\n',
#  '\nStafanie Taylor\n',
#  '\nNatalie Sciver\n',
#  '\nDeepti Sharma\n',
#  '\nJess Jonassen\n',
#  '\nAshleigh Gardner\n',
#  '\nDane van Niekerk\n',
#  '\nSophie Devine\n',
#  '\nKatherine Brunt\n']

# %%
allrounder_name = []
for i in all_rounder:
    allrounder_name.append(i.text.replace('\n',''))
allrounder_name[:9]
# Out:
# ['Ellyse Perry',
#  'Stafanie Taylor',
#  'Natalie Sciver',
#  'Deepti Sharma',
#  'Jess Jonassen',
#  'Ashleigh Gardner',
#  'Dane van Niekerk',
#  'Sophie Devine',
#  'Katherine Brunt']

# %%
rating3 = soup3.find_all('td', class_= 'table-body__cell rating')
rating3[:9]
# Out:
# [<td class="table-body__cell rating">418</td>,
#  <td class="table-body__cell rating">394</td>,
#  <td class="table-body__cell rating">365</td>,
#  <td class="table-body__cell rating">331</td>,
#  <td class="table-body__cell rating">307</td>,
#  <td class="table-body__cell rating">252</td>,
#  <td class="table-body__cell rating">243</td>,
#  <td class="table-body__cell rating">242</td>,
#  <td class="table-body__cell rating">239</td>]

# %%
all_rating = []
for i in rating3:
    all_rating.append(i.text)
all_rating[:9]
# Out:
# ['418', '394', '365', '331', '307', '252', '243', '242', '239']

# %%
team3 = soup3.find_all('span',class_ = 'table-body__logo-text')
team3[:9]
# Out:
# [<span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">WI</span>,
#  <span class="table-body__logo-text">ENG</span>,
#  <span class="table-body__logo-text">IND</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">AUS</span>,
#  <span class="table-body__logo-text">SA</span>,
#  <span class="table-body__logo-text">NZ</span>,
#  <span class="table-body__logo-text">ENG</span>]

# %%
all_team = []
for i in team3:
    all_team.append(i.text)
all_team[:9]
# Out:
# ['AUS', 'WI', 'ENG', 'IND', 'AUS', 'AUS', 'SA', 'NZ', 'ENG']

# %%
import pandas as pd 
allwomen_rank = pd.DataFrame({})
#bolwer_rank['Positions'] = pos_bow[:9]
allwomen_rank['All Rounder Name'] = allrounder_name[:9]
allwomen_rank['Team'] = all_team[:9]
allwomen_rank['Ratings'] = all_rating[:9]

allwomen_rank
# Out:
#    All Rounder Name Team Ratings
# 0      Ellyse Perry  AUS     418
# 1   Stafanie Taylor   WI     394
# 2    Natalie Sciver  ENG     365
# 3     Deepti Sharma  IND     331
# 4     Jess Jonassen  AUS     307
# 5  Ashleigh Gardner  AUS     252
# 6  Dane van Niekerk   SA     243
# 7     Sophie Devine   NZ     242
# 8   Katherine Brunt  ENG     239

# %%
top_row2 = pd.DataFrame({'All Rounder Name':['Marizanne Kapp'],'Team':['SA'], 'Ratings':[118]})
# Concat with old DataFrame and reset the Index.
allwomen_rank = pd.concat([top_row2, allwomen_rank]).reset_index(drop = True)
allwomen_rank
# Out:
#    All Rounder Name Team Ratings
# 0    Marizanne Kapp   SA     118
# 1      Ellyse Perry  AUS     418
# 2   Stafanie Taylor   WI     394
# 3    Natalie Sciver  ENG     365
# 4     Deepti Sharma  IND     331
# 5     Jess Jonassen  AUS     307
# 6  Ashleigh Gardner  AUS     252
# 7  Dane van Niekerk   SA     243
# 8     Sophie Devine   NZ     242
# 9   Katherine Brunt  ENG     239

# %% [markdown]
# # 7. Write a python program to scrape details of all the mobile phones under Rs. 20,000 listed on Amazon.in. The scraped data should include Product Name, Price, Image URL and Average Rating

# %%
url = 'https://www.amazon.in/s?k=all+the+mobile+phones+under+Rs.+20%2C000&ref=nb_sb_noss'

is_next = True
final_product_list = []
i = 1

while is_next:
    

    all_mobile_data = get_body(url)

    all_boxs = all_mobile_data.find_all('div',{'class':['s-result-item','s-asin']})

    
    # Find all the data of the currecnt page
    for one_box in all_boxs:
        try:
            inner_box = one_box.find('div',{'class':['a-section','a-spacing-medium']})

            product_name = inner_box.find('h2').find('span').text

            price = inner_box.find_all('div',{'class','sg-col-inner'})[1] \
                            .find('div',{'class','sg-row'}) \
                            .find('div',{'class','a-spacing-top-small'}) \
                            .find_all('span')[1].text

            if '₹' not in price:
                price = inner_box.find_all('div',{'class','sg-col-inner'})[1] \
                            .find('div',{'class','sg-row'}) \
                            .find('div',{'class','a-spacing-top-small'}) \
                            .find('span',{'class','a-offscreen'}).text

            image = inner_box.find('img')['src']
            average_rating = inner_box.find('i').find('span').text.split(' out of 5 stars')[0]

            final_product_list.append({
                'Product_Name': product_name, 
                'Price': price, 
                'Image URL': image, 
                'Average_Rating': average_rating
            })
        except Exception as e:
            continue
            
           
    # move to the next page
    
    i += 1
    try:
        a_pagination = all_mobile_data.find('ul',{'class','a-pagination'})
        s_pagination_item = all_mobile_data.find('a',{'class':['s-pagination-item','s-pagination-button']})
        try:
            if a_pagination != None:
                sub_url = all_mobile_data.find('ul',{'class','a-pagination'}).find("a", string=str(i))['href']
            elif s_pagination_item != None:
                find_element = all_mobile_data.find('a',{'class':['s-pagination-item','s-pagination-button']}).text
                if 'Previous' in find_element:
                    find_element = all_mobile_data.find_all('a',{'class':['s-pagination-item','s-pagination-button']})
                sub_url = all_mobile_data.find('a',{'class':['s-pagination-item','s-pagination-button']}).find_all("a", string=str(i))['href']

        except Exception as e1:
            sub_urls = all_mobile_data.find('a',{'class':['s-pagination-item','s-pagination-button']}).find_all("a", string=str(i))
            
        url = 'https://www.amazon.in' + sub_url
        
        is_next = True
    except Exception as e:
        is_next = False
        
pd.DataFrame(final_product_list)
# Out:
#                                          Product_Name    Price  \
# 0   Redmi 9A (Nature Green, 2GB RAM, 32GB Storage)...   ₹6,999
# 1   Panasonic Eluga i7 (2GB RAM, 16GB Storage, Fin...   ₹5,798
# 2   OPPO A31 (Fantasy White, 4GB RAM, 64GB Storage...  ₹10,990
# 3   Oppo A31 (Fantasy White, 6GB RAM, 128GB Storag...  ₹12,490
# 4   Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Storag...  ₹11,999
# 5   realme C11 (2021) (Cool Grey, 2GB RAM, 32GB St...   ₹6,999
# 6   Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage) | 2....   ₹8,999
# 7   Samsung Galaxy M02s (Black,4GB RAM, 64GB Stora...  ₹10,499
# 8   Tecno Spark 7 Pro (Spruce Green, 6GB RAM 64GB ...  ₹13,499
# 9   Tecno Spark 7 Pro (Magnet Black 6GB RAM 64GB S...  ₹13,199
# 10  iQOO Z3 5G (Cyber Blue, 8GB RAM, 128GB Storage...  ₹20,990
# 11  Samsung Galaxy M02s (Blue,4GB RAM, 64GB Storag...  ₹10,499
# 12  Redmi 9 (Carbon Black, 4GB RAM, 64GB Storage) ...   ₹8,999
# 13  Oppo A31 (Mystery Black, 6GB RAM, 128GB Storag...  ₹12,490
# ...

# %% [markdown]
# # 8. Write a python program to extract information about the local weather from the National Weather Service website of USA, https://www.weather.gov/ for the city, San Francisco. You need to extract data about 7 day extended forecast display for the city. The data should include period, short description, temperature and description.

# %%
url = 'https://forecast.weather.gov/MapClick.php?lat=37.777120000000025&lon=-122.41963999999996#.YRzDFHUzZNg'

# %%
forecast_boxs = get_body(url).find_all('div',{'class':'row-forecast'})

# %%
now = datetime.datetime.now()

# %%
all_day_name = []
for i in range(0,6):
    all_day_name.append((now + datetime.timedelta(days=i)).strftime("%A"))

# %%
final_data = []
for i, one_box in enumerate(forecast_boxs):
    
    forecast_label = one_box.find('div',{'class':'forecast-label'}).text 
    forecast_text = one_box.find('div',{'class':'forecast-text'}).text 
    
    if i == 0:
        period = 'Today'
    elif forecast_label in all_day_name:
        period = forecast_label
    else:
        continue
        
    sort_desc = forecast_text.split('.')[0]
    temprature = forecast_text.split(', with a ')[1].split('.')[0][-2:]    
    description = forecast_text
    final_data.append({'period': period,'sort_desc': sort_desc,'temprature': temprature,'description': description})
        
df = pd.DataFrame(final_data) 
df
# Out:
#      period                          sort_desc temprature  \
# 0     Today         Sunny, with a high near 72         72
# 1    Friday          Widespread haze after 1pm         74
# 2  Saturday         Sunny, with a high near 75         75
# 3    Sunday         Sunny, with a high near 73         73
# 4    Monday  Mostly sunny, with a high near 67         67
# 5   Tuesday         Sunny, with a high near 66         66
#
#                                          description
# 0  Sunny, with a high near 72. Light and variable...
# 1  Widespread haze after 1pm. Partly sunny, then ...
# 2  Sunny, with a high near 75. Light west southwe...
# 3                        Sunny, with a high near 73.
# 4                 Mostly sunny, with a high near 67.
# 5                        Sunny, with a high near 66.

# %% [markdown]
# # 9. Write a python program to scrape fresher job listings from ‘https://internshala.com/’. It should include job title, company name, CTC, and apply date.

# %%
url = 'https://internshala.com/fresher-jobs'
pagination_base_url = 'https://internshala.com/fresher-jobs/page-'

# %%
is_next = True
final_list = []
i = 1

while is_next:
    

    all_body_data = get_body(url)

    all_boxs = all_body_data.find_all('div',{'class':['visibilityTrackerItem']})

    
    # Find all the data of the currecnt page
    for one_box in all_boxs:
        try:
            inner_box = one_box.find('div',{'class':['internship_meta']})

            
            other_detail_item_row = inner_box.find('div',{'class':'internship_other_details_container'}) \
                .find_all('div',{'class','other_detail_item_row'})
            
            
            job_title = inner_box.find('div',{'class':'profile'}).find('a').text
            copany_name = inner_box.find('div',{'class':'company_name'}).find('a').text.replace('\n','')
            
            ctc = other_detail_item_row[0].find_all('div',{'class':'item_body'})[1].text.replace('\n','')
            apply_date = other_detail_item_row[1].find('div',{'class':'item_body'}).text

            final_list.append({
                'job_title': job_title, 
                'copany_name': copany_name, 
                'ctc': ctc, 
                'apply_date': apply_date
            })
        except Exception as e:
            continue
            
           
    # move to the next page
    
    i += 1
    try:
        total_pages = all_body_data.find('span',{'id':'total_pages'}).text
        if int(total_pages) != i-1:        
            url = pagination_base_url + str(i)
            print('fetching:',url)
            is_next = True
        else:
            is_next = False
            
    except Exception as e:
        print(e)
        is_next = False
        
pd.DataFrame(final_list)
# Out:
# fetching: https://internshala.com/fresher-jobs/page-2
# fetching: https://internshala.com/fresher-jobs/page-3
# fetching: https://internshala.com/fresher-jobs/page-4
# fetching: https://internshala.com/fresher-jobs/page-5
# fetching: https://internshala.com/fresher-jobs/page-6
# fetching: https://internshala.com/fresher-jobs/page-7
#                                      job_title  \
# 0                            OMNI SPORT LEADER
# 1    Executive/Senior Executive - Partnerships
# 2                            Executive - Sales
# 3                  Junior Operations Executive
# 4                    Student Success - Teacher
# ..                                         ...
# 245               Business Development Manager
# 246                  Patent Research Associate
# 247                               Data Analyst
# 248                            Software Tester
# 249                         Operations Manager
#
#                                            copany_name  \
# ...

# %% [markdown]
# # 10. Write a python program to scrape house details from https://www.nobroker.in/ for any location. It should include house title, location, area, emi and price

# %%
    url = 'https://www.nobroker.in/property/sale/bangalore/Creditguru?searchParam=W3sibGF0IjoxMi45ODAwNzU3LCJsb24iOjc3LjUxMTQ0OTM5OTk5OTk5LCJwbGFjZUlkIjoiQ2hJSksyNDFDRFE4cmpzUnFibWt5M2V4T0V3IiwicGxhY2VOYW1lIjoiQ3JlZGl0Z3VydSIsInNob3dNYXAiOmZhbHNlfV0=&radius=2.0'

# %%
get_boxes = get_body(url).find_all('div',{'class':'nb__2JHKO'})

# %%
final_data = []
for one_box in get_boxes:
    
    house_title = one_box.find('h2').text
    location = one_box.find('div',{'class':'nb__2CMjv'}).text
    
    inner_box = one_box.find('div',{'class':'nb__17R6o'})
    
    area = inner_box.find('div',{'class':'nb__3oNyC'}).text
    emi = inner_box.find('div',{'id':'roomType'}).text
    price = inner_box.find('div',{'id':'minDeposit'}).find('span').text
    
    final_data.append({
        'house_title': house_title,
        'location': location,
        'area': area, 
        'emi': emi, 
        'price': price
    })

df = pd.DataFrame(final_data)
df
# Out:
#                                          house_title  \
# 0            4 BHK Flat  For Sale  In Naagarabhaavi
# 1  2 BHK In Independent House  For Sale  In Bda L...
# 2  2 BHK Flat  For Sale  In Vaibhava Apartment  I...
# 3  2 BHK Flat  For Sale  In Sree Sai Park View  I...
# 4           4+ BHK Flat  For Sale  In Naagarabhaavi
# 5            3 BHK Flat  For Sale  In Naagarabhaavi
# 6  4 BHK In Independent House  For Sale  In Nagar...
# 7  2 BHK In Independent House  For Sale  In Nagar...
# 8              4+ BHK Flat  For Sale  In Nagarbhavi
# 9              4 BHK Flat  For Sale  In Nagarbhavi
#
#                                             location        area  \
# 0  standalone building, 2nd Stage near BDA COMPLE...  3,998 sqft
# 1  Independent House, 3rd Block Near  BDA COMPLEX...  1,800 sqft
# 2         BDA Layout, 2nd Stage, near B.D.A. Complex    800 sqft
# 3  Nagarbhavi 2nd Stage , Near BDA complex next t...    745 sqft
# ...
